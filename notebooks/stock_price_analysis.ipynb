# %%
# Task 2: Quantitative Analysis of Stock price
## import liberaries
import os
import sys
import pandas as pd 
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import talib as ta
sys.path.insert(0, os.path.dirname(os.getcwd()))
# import Stock_Price_Analyzer from src
from src.stock_price_analyzer import *

# %%
# get data path
folder_path = '../data/yfinance_data'
# Automatically merge the data and assign to stock_analyzer
stock_analyzer = StockPriceAnalyzer(folder_path=folder_path)
# Access the merged data
print(stock_analyzer.data.head())
# save the merged data to a CSV file
# Out:
#          Date      Open      High       Low     Close  Adj Close     Volume  \
# 0  2004-08-19  2.490664  2.591785  2.390042  2.499133   2.496292  897427216
# 1  2004-08-20  2.515820  2.716817  2.503118  2.697639   2.694573  458857488
# 2  2004-08-23  2.758411  2.826406  2.716070  2.724787   2.721690  366857939
# 3  2004-08-24  2.770615  2.779581  2.579581  2.611960   2.608991  306396159
# 4  2004-08-25  2.614201  2.689918  2.587302  2.640104   2.637103  184645512
#
#    Dividends  Stock Splits stock_symbol
# 0        0.0           0.0         GOOG
# 1        0.0           0.0         GOOG
# 2        0.0           0.0         GOOG
# 3        0.0           0.0         GOOG
# 4        0.0           0.0         GOOG

# %%
# Display the first five row datas after merging
stock_analyzer.data.head()
# Out:
#          Date      Open      High       Low     Close  Adj Close     Volume  \
# 0  2004-08-19  2.490664  2.591785  2.390042  2.499133   2.496292  897427216
# 1  2004-08-20  2.515820  2.716817  2.503118  2.697639   2.694573  458857488
# 2  2004-08-23  2.758411  2.826406  2.716070  2.724787   2.721690  366857939
# 3  2004-08-24  2.770615  2.779581  2.579581  2.611960   2.608991  306396159
# 4  2004-08-25  2.614201  2.689918  2.587302  2.640104   2.637103  184645512
#
#    Dividends  Stock Splits stock_symbol
# 0        0.0           0.0         GOOG
# 1        0.0           0.0         GOOG
# 2        0.0           0.0         GOOG
# 3        0.0           0.0         GOOG
# 4        0.0           0.0         GOOG

# %%
# make sure the dataframe includes columns like Open, High, Low, Close, and Volume.
stock_analyzer.data.columns
# Out:
# Index(['Date', 'Open', 'High', 'Low', 'Close', 'Adj Close', 'Volume',
#        'Dividends', 'Stock Splits', 'stock_symbol'],
#       dtype='object')

# %%
# Calculate technical indicators using TA-Lib and desplay the data
stock_data=stock_analyzer.calculate_technical_indicators(stock_analyzer.data)
stock_data
# Out:
#              Date        Open        High         Low       Close   Adj Close  \
# 0      2004-08-19    2.490664    2.591785    2.390042    2.499133    2.496292
# 1      2004-08-20    2.515820    2.716817    2.503118    2.697639    2.694573
# 2      2004-08-23    2.758411    2.826406    2.716070    2.724787    2.721690
# 3      2004-08-24    2.770615    2.779581    2.579581    2.611960    2.608991
# 4      2004-08-25    2.614201    2.689918    2.587302    2.640104    2.637103
# ...           ...         ...         ...         ...         ...         ...
# 45423  2024-07-24  224.000000  224.800003  217.130005  218.539993  218.287323
# 45424  2024-07-25  218.929993  220.850006  214.619995  217.490005  217.238556
# 45425  2024-07-26  218.699997  219.490005  216.009995  217.960007  217.708008
# 45426  2024-07-29  216.960007  219.300003  215.750000  218.240005  217.987686
# 45427  2024-07-30  219.190002  220.330002  216.119995  218.800003  218.547043
#
#           Volume  Dividends  Stock Splits stock_symbol       Data         SMA  \
# 0      897427216        0.0           0.0         GOOG 2004-08-19         NaN
# 1      458857488        0.0           0.0         GOOG 2004-08-20         NaN
# 2      366857939        0.0           0.0         GOOG 2004-08-23         NaN
# 3      306396159        0.0           0.0         GOOG 2004-08-24         NaN
# 4      184645512        0.0           0.0         GOOG 2004-08-25         NaN
# ...          ...        ...           ...          ...        ...         ...
# 45423   61777600        0.0           0.0         AAPL 2024-07-24  224.228500
# 45424   51391200        0.0           0.0         AAPL 2024-07-25  224.440500
# 45425   41601300        0.0           0.0         AAPL 2024-07-26  224.633500
# 45426   36311800        0.0           0.0         AAPL 2024-07-29  225.014500
# 45427   41643800        0.0           0.0         AAPL 2024-07-30  225.117001
#
#              RSI         EMA      MACD  MACD_Signal
# 0            NaN         NaN       NaN          NaN
# 1            NaN         NaN       NaN          NaN
# 2            NaN         NaN       NaN          NaN
# 3            NaN         NaN       NaN          NaN
# 4            NaN         NaN       NaN          NaN
# ...          ...         ...       ...          ...
# 45423  48.687742  222.376929  4.662717     6.678882
# 45424  47.386437  221.911508  3.748082     6.092722
# 45425  48.055700  221.535174  3.026267     5.479431
# 45426  48.476184  221.221349  2.448591     4.873263
# 45427  49.359115  220.990744  2.012764     4.301163
#
# [45428 rows x 16 columns]

# %%
stock_analyzer.visualize_stocks(stock_analyzer.data)
